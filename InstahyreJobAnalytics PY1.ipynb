# %%
import selenium
from selenium.webdriver import chrome
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
# Setting up the Selenium web driver to automate clicking the button
driver = webdriver.Chrome(options=options)

# Maximize browser window size
driver.maximize_window()

# Make a GET request to the URL
driver.get(base_url)

job_data = []

# Finding data on webpage
for i in range(1,71):
    print("Page", i)

    driver.implicitly_wait(10)

    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    # Find all HTML elements with the specified class name
    cards = soup.find_all(class_=class_name)
    
    # %%
    # Loop through each card and open its link to get its contents
    for card in cards:
        link = card.find('a')['href']

        print("Navigating to:", link)
        content_driver = webdriver.Chrome(options=options)
        content_driver.get(link)

        try:
            alert = content_driver.switch_to.alert
            alert.accept()
        except:
            pass

        content_html = content_driver.page_source
        content_soup = BeautifulSoup(content_html, 'html.parser')

        # Wait for page to load
        content_driver.implicitly_wait(10)
        
        job_id          = int(link.split('-')[1])
        job_title       = content_soup.find("h1").text.strip()
        company_name    = content_soup.find(class_="company-name").text.strip()
        experience      = content_soup.find(class_="experience").text.strip()
        job_locations   = content_soup.find(class_="job-locations").text.strip().replace(experience, "")
        HR_name         = content_soup.find(class_="rec-name").text.strip()
        founded_in_elem = content_soup.find("div", {"ng-if": "employer.company_founded"})
        employees_count = content_soup.find("div", {"ng-if": "employer.employee_count"})
        employees_count = employees_count.text.strip() if employees_count and employees_count.text else employees_count
        skills_children = content_soup.find(class_="tags job-description-skills")
        skills_children = skills_children.children if skills_children and skills_children.children else [].append(skills_children)

        skills_list     = []
        
        if skills_children is not None:
            for skill in skills_children:
                skill = skill.text.strip()
                if (skill and skill != "\\n"):
                    skills_list.append(skill)
        skills= "N/A" if skills_list is None      else ", ".join(skills_list)
        founded_in= "N/A" if founded_in_elem is None  else founded_in_elem.text.strip()
        job_data.append({
            "company_name"      : company_name,
            "job_title"         : job_title,
            "job_locations"     : job_locations,
            "experience"        : experience,
            "hr_name"           : HR_name,
            "founded_in"        : founded_in,
            "employees_count"   : employees_count,
            "skills"            : skills,
            "job_id"            : job_id
        })

        # Return to the previous page
        content_driver.back()
        content_driver.quit()
    
    driver.implicitly_wait(20)
        
    # Click the button to go to the next page
    next_button = driver.find_element(By.CSS_SELECTOR, '[ng-click="nextPage()"]')

    if next_button is not None:
        next_button.click()
    else:
        print("No next page button found.")
# Out:
# Page 1
# Navigating to: https://www.instahyre.com/job-249688-service-ops-at-cogoport-gurgaon/
# Navigating to: https://www.instahyre.com/job-252261-marketing-intern-at-hubilo-work-from-home/
# Navigating to: https://www.instahyre.com/job-251583-sr-revenue-analyst-at-ringcentral-bangalore/
# Navigating to: https://www.instahyre.com/job-249768-account-manager-at-squadstack-noida/
# Navigating to: https://www.instahyre.com/job-250986-demand-generation-associate-at-squadstack-bangalore-noida/
# Navigating to: https://www.instahyre.com/job-249767-process-trainers-at-squadstack-work-from-home/
# Navigating to: https://www.instahyre.com/job-249770-sr-operations-analyst-at-squadstack-noida/
# Navigating to: https://www.instahyre.com/job-249702-key-account-manager-sales-at-thence-bangalore/
# Navigating to: https://www.instahyre.com/job-251581-operations-intern-at-zenda-delhi-hyderabad-mumbai/
# Navigating to: https://www.instahyre.com/job
2-bangalore/
# Navigating to: https://www.instahyre.com/job-252984-senior-ui-engineer-at-out-of-the-blue-work-from-home/
# Navigating to: https://www.instahyre.com/job-252976-software-backend-developer-t500-7370-at-owens-minor-work-from-home/
# Navigating to: https://www.instahyre.com/job-252961-backend-engineer-at-rupicard-bangalore/
# Navigating to: https://www.instahyre.com/job-252959-go-developer-at-uptycs-bangalore/
# Page 11
# Navigating to: https://www.instahyre.com/job-252943-policy-advisor-at-acko-bangalore/
# Navigating to: https://www.instahyre.com/job-252954-principal-engineer-infra-at-caastle-delhi/
# Navigating to: https://www.instahyre.com/job-252948-onboarding-specialist-at-colmore-bangalore/
# Navigating to: https://www.instahyre.com/job-252952-talend-matillion-developer-at-cs-soft-solutions-work-from-home/
# Navigating to: https://www.instahyre.com/job-252957-java-developer-at-denovo-systems-chennai/
# Navigating to: https://www.instahyre.com/job-252958-team-lead-at-graymatter-software-services-bangalore/
# Navigating to: https://www.instahyre.com/job-252949-business-development-manager-at-jumpingminds-2-delhi/
# Navigating to: https://www.instahyre.com/job-252951-sales-executive-at-prominance-window-systems-jaipur/
# Navigating to: https://www.instahyre.com/job-252956-senior-it-manager-at-the-ageless-clinic-mumbai/
# Navigating to: https://www.instahyre.com/job-252946-senior-manager-accounts-at-the-ageless-clinic-mumbai/
# Page 12
# Navigating to: https://www.instahyre.com/job-252942-siebel-developer-eai-at-able-jobs-2-delhi/
# Navigating to: https://www.instahyre.com/job-252932-sr-backend-developer-at-adobe-bangalore/
# Navigating to: https://www.instahyre.com/job-252926-rpa-developer-lead-at-ltimindtree-2-bangalore/
# Navigating to: https://www.instahyre.com/job-252918-sde-iv-at-mystifly-bangalore/
# Navigating to: https://www.instahyre.com/job-252920-lead-data-engineer-at-physicswallah-noida/
# Navigating to: https://www.instahyre.com/job-252921-lead-data-engineer-at-physicswallah-bangalore/
# Navigating to: https://www.instahyre.com/job-252925-lead-data-engineer-at-physicswallah-bangalore/
# Navigating to: https://www.instahyre.com/job-252939-dot-net-developer-at-the-famous-pune/
# Navigating to: https://www.instahyre.com/job-252937-dot-net-developer-at-the-famous-mumbai/
# Navigating to: https://www.instahyre.com/job-252922-java-developer-at-trustt-bangalore/
# Page 13
# Navigating to: https://www.instahyre.com/job-252913-assistant-manager-data-engineer-at-accenture-2-bangalore/
# Navigating to: https://www.instahyre.com/job-252901-order-allocation-manager-at-anko-bangalore/
# Navigating to: https://www.instahyre.com/job-252908-senior-developer-full-stack-at-delta-air-lines-bangalore/
# Navigating to: https://www.instahyre.com/job-252907-senior-system-engineer-it-at-delta-air-lines-bangalore/
# Navigating to: https://www.instahyre.com/job-252909-data-engineer-with-gcp-at-globallogic-bangalore/
# Navigating to: https://www.instahyre.com/job-252899-senior-data-engineer-aws-at-globallogic-bangalore/
# Navigating to: https://www.instahyre.com/job-252917-product-manager-at-jumbotail-bangalore/
# Navigating to: https://www.instahyre.com/job-252904-sr-product-designer-at-lendenclub-mumbai/
# Navigating to: https://www.instahyre.com/job-252897-lead-devops-engineer-at-w-energy-software-work-from-home/
# Navigating to: https://www.instahyre.com/job-252915-product-marketing-specialist-at-zoho-corporation-bangalore/
# Page 14
# Navigating to: https://www.instahyre.com/job-252895-graphic-designer-at-abcoffee-mumbai/
# Navigating to: https://www.instahyre.com/job-252880-backend-engineer-at-alaan-bangalore/
# Navigating to: https://www.instahyre.com/job-252884-net-developer-at-aura-egaming-dubai/
# Navigating to: https://www.instahyre.com/job-252679-ai-engineer-at-whatfix-bangalore/
# Page 30
# Navigating to: https://www.instahyre.com/job-252668-engineering-manager-backend-at-avataar-2-bangalore/
# Navigating to: https://www.instahyre.com/job-252669-data-engineer-2-at-commerceiq-chennai/
# Navigating to: https://www.instahyre.com/job-252664-enterprise-data-architect-at-deutsche-telekom-digital-labs-gurgaon/
# Navigating to: https://www.instahyre.com/job-252670-enterprise-sales-representative-at-edyoda-bangalore/
# Navigating to: https://www.instahyre.com/job-252666-head-of-design-ux-at-infeedo-2-work-from-home/
# Navigating to: https://www.instahyre.com/job-252665-software-engineer-at-inspire-brands-hyderabad/
# Navigating to: https://www.instahyre.com/job-252663-sap-fico-consultant-at-ltimindtree-2-hyderabad/
# Navigating to: https://www.instahyre.com/job-252662-business-development-manager-at-macgence-noida/
# Navigating to: https://www.instahyre.com/job-252667-presales-executive-at-macgence-noida/
# Navigating to: https://www.instahyre.com/job-252671-datastage-developer-r24-at-tredence-inc-bangalore/
# 338
# job_data [{'company_name': 'Cogoport', 'job_title': 'Service Ops   (Drive)', 'job_locations': 'Gurgaon', 'experience': '0-2 Years', 'hr_name': 'Revati Agnihotri', 'founded_in': 'Founded in 2016', 'employees_count': '200 - 500 employees', 'skills': 'Data Entry, Documentation, Operations Management', 'job_id': 249688}, {'company_name': 'Hubilo', 'job_title': 'Marketing Intern   (Drive)', 'job_locations': 'Work From Home', 'experience': '0-1 Years', 'hr_name': 'Tejashwini Kanashetti', 'founded_in': 'Founded in 2015', 'employees_count': '50 - 200 employees', 'skills': 'Digital Marketing, Marketing Communication', 'job_id': 252261}, {'company_name': 'RingCentral', 'job_title': 'Sr. Revenue Analyst   (Drive)', 'job_locations': 'Bangalore', 'experience': '2-4 Years', 'hr_name': 'Azhar Ahmed', 'founded_in': 'Founded in 2003', 'employees_count': 'More than 1000 employees', 'skills': 'Accounting, Chartered Accountant, ERP Implementation, Finance, NetSuite', 'job_id': 251583}, {'company_name': '', 'job_title': '', 'job_locations': '', 'experience': '- Years', 'hr_name': 'Marsina Waffa', 'founded_in': 'N/A', 'employees_count': None, 'skills': '', 'job_id': 249768}, {'company_name': '', 'job_title': '', 'job_locations': '', 'experience': '- Years', 'hr_name': 'Marsina Waffa', 'founded_in': 'N/A', 'employees_count': None, 'skills': '', 'job_id': 250986}, {'company_name': '', 'job_title': '', 'job_locations': '', 'experience': '- Years', 'hr_name': 'Marsina Waffa', 'founded_in': 'N/A', 'employees_count': None, 'skills': '', 'job_id': 249767}, {'company_name': '', 'job_title': '', 'job_locations': '', 'experience': '- Years', 'hr_name': 'Marsina Waffa', 'founded_in': 'N/A', 'employees_count': None, 'skills': '', 'job_id': 249770}, {'company_name': 'Thence', 'job_title': 'Key Account Manager - Sales   (Drive)', 'job_locations': 'Bangalore', 'experience': '4-8 Years', 'hr_name': 'Sabari Prasad', 'founded_in': 'Founded in 2012', 'employees_count': '50 - 200 employees', 'skills': 'Corporate Sales, Key Account Management, LinkedIn Sales Navigator', 'job_id': 249702}, {'company_name': '', 'job_title': '', 'job_locations': '', 'experience': '- Years', 'hr_name': 'Meenal Sharma', 'founded_in': 'N/A', 'employees_count': None, 'skills': '', 'job_id': 251581}, {'company_name': '', 'job_title': '', 'job_locations': '', 'experience': '- Years', 'hr_name': 'Vasumathi Govindaraj', 'founded_in': 'N/A', 'employees_count': None, 'skills': '', 'job_id': 252023}, {'company_name': '', 'job_title': '', 'job_locations': '', 'experience': '- Years', 'hr_name': 'Revati Agnihotri', 'founded_in': 'N/A', 'employees_count': None, 'skills': '', 'job_id': 249688}, {'company_name': '', 'job_title': '', 'job_locations': '', 'experience': '- Years', 'hr_name': 'Tejashwini Kanashetti', 'founded_in': 'N/A', 'employees_count': None, 'skills': '', 'job_id': 252261}, {'company_name': '', 'job_title': '', 'job_locations': '', 'experience': '- Years', 'hr_name': 'Azhar Ahmed', 'founded_in': 'N/A', 'employees_count': None, 'skills': '', 'job_id': 251583}, {'company_name': 'SquadStack', 'job_title': 'Account Manager   (Drive)', 'job_locations': 'Noida', 'experience': '2-5 Years', 'hr_name': 'Marsina Waffa', 'founded_in': 'Founded in 2014', 'employees_count': '50 - 200 employees', 'skills': 'Key Account Management, Microsoft Excel, Sales Forecasting, Sales Operations', 'job_id': 249768}, {'company_name': 'SquadStack', 'job_title': 'Demand Generation Associate   (Drive)', 'job_locations': 'Bangalore, Noida', 'experience': '1-3 Years', 'hr_name': 'Marsina Waffa', 'founded_in': 'Founded in 2014', 'employees_count': '50 - 200 employees', 'skills': 'Business Development, CRM, Demand Generation, Email Marketing, Lead Generation, LinkedIn Marketing', 'job_id': 250986}, {'company_name': 'SquadStack', 'job_title': 'Process Trainers   (Drive)', 'job_locations': 'Work From Home', 'experience': '1-5 Years', 'hr_name': 'Marsina Waffa', 'founded_in': 'Founded in 2014', 'employees_count': '50 - 200 e ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /var/folders/zm/wvxfnrjd7y114qkssn4fp2yr0000gq/T/ipykernel_21053/2496007165.py in <module>
#     102
#     103 # Write the DataFrame to an Excel file with the specified columns
# --> 104 df.to_excel('D:/job_data.xlsx', columns=['company_name', 'job_title', 'job_locations', 'experience', 'hr_name', 'founded_in', 'employees_count', 'skills','job_id'], index=False)
#     105 # %%
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2343             inf_rep=inf_rep,
#    2344         )
# -> 2345         formatter.write(
#    2346             excel_writer,
#    2347             sheet_name=sheet_name,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/formats/excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     886             # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     887             # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 888             writer = ExcelWriter(  # type: ignore[abstract]
#     889                 writer, engine=engine, storage_options=storage_options
#     890             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_xlsxwriter.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     189             raise ValueError("Append mode is not supported with xlsxwriter!")
#     190
# --> 191         super().__init__(
#     192             path,
#     193             engine=engine,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/excel/_base.py in __init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#    1104         )
#    1105         if not isinstance(path, ExcelWriter):
# -> 1106             self.handles = get_handle(
#    1107                 path, mode, storage_options=storage_options, is_text=False
#    1108             )
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     692     # Only for write methods
#     693     if "r" not in mode and is_path:
# --> 694         check_parent_directory(str(handle))
#     695
#     696     if compression:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/io/common.py in check_parent_directory(path)
#     566     parent = Path(path).parent
#     567     if not parent.is_dir():
# --> 568         raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#     569
#     570
#
# OSError: Cannot save file into a non-existent directory: 'D:'

# %%
#Converting to DataFrame

df=pd.DataFrame(job_data)

# %%
df
# Out:
#        company_name                      job_title   job_locations  \
# 0          Cogoport          Service Ops   (Drive)         Gurgaon
# 1            Hubilo     Marketing Intern   (Drive)  Work From Home
# 2       RingCentral  Sr. Revenue Analyst   (Drive)       Bangalore
# 3
# 4
# ..              ...                            ...             ...
# 333  Inspire Brands              Software Engineer       Hyderabad
# 334     LTIMindtree            SAP FICO Consultant       Hyderabad
# 335        Macgence   Business Development Manager           Noida
# 336        Macgence             Presales Executive           Noida
# 337    Tredence Inc      Datastage Developer - R24       Bangalore
#
#      experience                hr_name       founded_in  \
# 0     0-2 Years       Revati Agnihotri  Founded in 2016
# 1     0-1 Years  Tejashwini Kanashetti  Founded in 2015
# 2     2-4 Years            Azhar Ahmed  Founded in 2003
# 3       - Years          Marsina Waffa              N/A
# 4       - Years          Marsina Waffa              N/A
# ..          ...                    ...              ...
# 333   2-4 Years         Palak Parashar  Founded in 2018
# 334  7-12 Years              Md Naveed  Founded in 1996
# 335   1-3 Years             Priyanka U  Founded in 2020
# 336   3-5 Years             Priyanka U  Founded in 2020
# 337   3-5 Years      Pinnacle Consultz  Founded in 2013
#
#               employees_count  \
# 0         200 - 500 employees
# 1          50 - 200 employees
# 2    More than 1000 employees
# 3                        None
# 4                        None
# ..                        ...
# 333  More than 1000 employees
# 334  More than 1000 employees
# 335         10 - 50 employees
# 336         10 - 50 employees
# 337      500 - 1000 employees
#
#                                                 skills  job_id
# 0     Data Entry, Documentation, Operations Management  249688
# 1           Digital Marketing, Marketing Communication  252261
# 2    Accounting, Chartered Accountant, ERP Implemen...  251583
# 3                                                       249768
# 4                                                       250986
# ..                                                 ...     ...
# 333                   Java, Spring Boot, Microservices  252665
# 334  SAP FICO, SAP ERP, Taxation, Finance, SAP Modu...  252663
# 335  Sales, Customer Service, Media Relations, CRM,...  252662
# 336  Sales, Telecalling, Transcription, Marketing, ...  252667
# 337          IBM DataStage, Azure, Teradata, BTEQ, ETL  252671
#
# [338 rows x 9 columns]
